# %% [markdown]
# <a href="https://colab.research.google.com/github/greek-nlp/benchmark/blob/main/nlp_gr_attribution_adversarial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 1rvvmpZ5Ndjj4GyydIVYoXBByrayZ6Bnl
# !gdown 1_UNRIBKVMGY6iY6hN06EW4ZH2mibVwjq
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1rvvmpZ5Ndjj4GyydIVYoXBByrayZ6Bnl
# To: /content/openbook_test_excerpts.csv.gz
# 100% 299k/299k [00:00<00:00, 87.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_UNRIBKVMGY6iY6hN06EW4ZH2mibVwjq
# To: /content/gutenberg_test_excerpts.csv.gz
# 100% 37.9k/37.9k [00:00<00:00, 55.3MB/s]

# %%
import pandas as pd
ob = pd.read_csv('openbook_test_excerpts.csv.gz', index_col=0)
gb = pd.read_csv('gutenberg_test_excerpts.csv.gz', index_col=0)

# %%
gb.sample(3)
# Out:
#                  id          title                author  type  publishedYear  \
# Unnamed: 0
# 174         PG31444  Παλιές Αγάπες  Karkavitsas, Andreas   NaN           1919
# 173         PG31631  Ο αρχαιολόγος  Karkavitsas, Andreas   NaN           1904
# 174         PG31444  Παλιές Αγάπες  Karkavitsas, Andreas   NaN           1919
#
#             isbn  filename  postUrl  attachmentUrl  authorYearOfBirth  ...  \
# Unnamed: 0                                                             ...
# 174          NaN       NaN      NaN            NaN             1866.0  ...
# 173          NaN       NaN      NaN            NaN             1866.0  ...
# 174          NaN       NaN      NaN            NaN             1866.0  ...
#
#                     publisher  excerpt_num  \
# Unnamed: 0
# 174         project_gutenberg           10
# 173         project_gutenberg            5
# 174         project_gutenberg            1
#
# ...
